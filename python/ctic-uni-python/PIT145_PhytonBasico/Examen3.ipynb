# %%
import math as m
def esPrimo(num):
  count = 0
  for i in range(1,num):
    if num % i == 0:
      count+=1
  if count == 1:
    return True

count_primos = 0
for i in range(666,6666):
  if esPrimo(i) == True:
    count_primos = count_primos + 1
print('primos ', count_primos)
# Out:
# primos  738

# %%
import math as m
def esPrimo(num):
  count = 0
  for i in range(1,num):
    if num % i == 0:
      count+=1
  if count == 1:
    return True

count_primos = 0
for i in range(99855,99885):
  if esPrimo(i) == True:
    print(i)
# Out:
# 99859
# 99871
# 99877
# 99881

# %%
num = int(input('numero: '))
suma = 0
for i in range(1,num):
  if num % i == 0:
    suma = suma + i
if suma == num:
  print('es perfecto')
