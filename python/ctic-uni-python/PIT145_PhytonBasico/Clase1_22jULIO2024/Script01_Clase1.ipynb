# %%
# Esto es un comentario

# Comentemos
# varias
# lineas de
# codigo Phyton

# No olvidar que siempre es recomendable recomendable
# comentar el codgio muy bien

# %%
# Declarar / definir variables

x = True
y = 1
nombre = "Rodrigo Jara"
complejo1 = 3. + 6j

# %%
# Definamos otras variables
edad = 42
peso = 62
estatura = 1.71
apellidoPaterno = "Jara"
apellidoMaterno = "Espinoza"
opt1 = False
cm2 = 0.5 + 3.1415j

# %%
# Algunas caracteristicas de phyton

# Phyton en un lenguaje de programacion interpretado
# Phyton es un lenguaje de programacion de tipado dinamico
edad = "old"

# Phyton es un lenguaje eminentemente orientado a objetos

# %%
# Funcion type
type(cm2)
# Out:
# complex

# %%
type(opt1)
# Out:
# bool

# %%
# Fechas
fecha1 = "22/07/2024"
fecha2 = "22 de julio del 2024"

# %%
type(fecha1)
# Out:
# str

# %%
# nulo
x = None
type(x)
# Out:
# NoneType

# %%
# Declaracion de variables variables en una misma linea
c1, c2, c3 = 12, 8.5, "PrimeraClase"

# %%
c1
# Out:
# 12

# %%
c2
# Out:
# 8.5

# %%
c3
# Out:
# 'PrimeraClase'

# %%
# !nproc
# Out:
# 2
