# %% [markdown]
# # Herencia

# %%
# Implementemos nuestra propia clase Base (Clase Abstracta / Super Clase) : Clase Persona

# Persona :
  # Tiene una fecha de nacimiento (modulo datetime) : lista de tres numeros (yyyy, mm, dd)
    # Hay que tener ciertas consideraciones :
      # La primera componente de esta lista representa al año : desde 1900 hasta el presente año
      # La segunda componente de esta lista representa al mes : debe ser un numero entero del 1 al 12
      # La tercera componente de esta lista representa al dia : debe ser un entero de 1 a 31
  # Posee un dni (string de 8 caracteres)
  # Posee uno o más nombres : Dato de tipo lista
  # Posee un apellido paterno : Dato de tipo lista
  # Posee un apellido materno : Dato de tipo lista
  # Tiene un sexo : string de un solo caracter (M o F)
  # Puede comunicarse (devolver una cadena de caracteres)

# %% [markdown]
# ## Modulo DATETIME

# %%
# Carguemos el modulo datetime
import datetime

# %%
# Qué compone el modulo datetime
dir(datetime)
# Out:
# ['MAXYEAR',
#  'MINYEAR',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'date',
#  'datetime',
#  'datetime_CAPI',
#  'sys',
#  'time',
#  'timedelta',
#  'timezone',
#  'tzinfo']

# %%
# Primera constante definida en el modulo datetime
datetime.MAXYEAR
# Out:
# 9999

# %%
# Segunda constante definida en el modulo datetime
datetime.MINYEAR
# Out:
# 1

# %%
# Analicemos al miembro date de la lista que se obtiene de la funcion dir para el modulo datetime
help(datetime.date)
# Out:
# Help on class date in module datetime:
#
# class date(builtins.object)
#  |  date(year, month, day) --> date object
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(...)
#  |      Formats self with strftime.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __radd__(self, value, /)
#  |      Return value+self.
#  |
#  |  __reduce__(...)
#  |      __reduce__() -> (cls, state)
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
# ...

# %%
# De la celda anterior, aprendimos que datetime.date es una clase => que esta clase
# (date) puede servir para instanciar un objeto
d1 = datetime.date()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-8ce92d103675> in <cell line: 3>()
#       1 # De la celda anterior, aprendimos que datetime.date es una clase => que esta clase
#       2 # (date) puede servir para instanciar un objeto
# ----> 3 d1 = datetime.date()
#
# TypeError: function missing required argument 'year' (pos 1)

# %%
# La creacion de d1 mostró fundamentalmente dos cosas:
  # Cada vez que por primera vez comencemos a estudiar (a desarrollar) un modulo lo primero es leer a profundidad la documentacion
  # Forma correcta de interpretar la documentacion proveida por help

d2 = datetime.date(1958, 6, 12)

# %%
d2
# Out:
# datetime.date(1958, 6, 12)

# %%
# Tipo de dato
type(d2)
# Out:
# datetime.date

# %%
# Funcion isinstance
isinstance(d2, datetime.date)
# Out:
# True

# %%
# Lista de metodos que se puede aplicar a un objeto de tipo como el de d2
dir(d2)
# Out:
# ['__add__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  'ctime',
#  'day',
#  'fromisocalendar',
#  'fromisoformat',
#  'fromordinal',
#  'fromtimestamp',
#  'isocalendar',
#  'isoformat',
#  'isoweekday',
#  'max',
#  'min',
#  'month',
#  'replace',
#  'resolution',
#  'strftime',
#  'timetuple',
#  'today',
#  'toordinal',
#  'weekday',
#  'year']

# %%
# Documentacion del miembro year
help(d2.year)
# Out:
# Help on int object:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Built-in subclasses:
#  |      bool
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
# ...

# %%
# De la celda anterior hemos de reconocer que el miembro year es un atributo :
# pues este devuelve un tipo de dato int
d2.year
# Out:
# 1958

# %%
# Docuemntacion de weekday
help(d2.weekday)
# Out:
# Help on built-in function weekday:
#
# weekday(...) method of datetime.date instance
#     Return the day of the week represented by the date.
#     Monday == 0 ... Sunday == 6

# %%
d2.weekday()

# Corresponde a un jueves
# Out:
# 3

# %%
# Analicemos al miembro datetime.datetime de dir(datetime)
help(datetime.datetime)
# Out:
# Help on class datetime in module datetime:
#
# class datetime(date)
#  |  datetime(year, month, day[, hour[, minute[, second[, microsecond[,tzinfo]]]]])
#  |
#  |  The year, month and day arguments are required. tzinfo may be None, or an
#  |  instance of a tzinfo subclass. The remaining arguments may be ints.
#  |
#  |  Method resolution order:
#  |      datetime
#  |      date
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
# ...

# %%
# Creacion de un objeto instancia de la clase datetime.datetime
f1 = datetime.datetime(1958, 6, 12)

# %%
# Mostremos f1 (__repr__)
f1
# Out:
# datetime.datetime(1958, 6, 12, 0, 0)

# %%
# Mostremos f1 (__str__)
print(f1)
# Out:
# 1958-06-12 00:00:00

# %%
# Tipo de dato
type(f1)
# Out:
# datetime.datetime

# %%
# Lista de metodos que se puede aplicar a un objeto como f1
dir(f1)
# Out:
# ['__add__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  'astimezone',
#  'combine',
#  'ctime',
#  'date',
#  'day',
#  'dst',
#  'fold',
#  'fromisocalendar',
#  'fromisoformat',
#  'fromordinal',
#  'fromtimestamp',
#  'hour',
#  'isocalendar',
#  'isoformat',
#  'isoweekday',
#  'max',
#  'microsecond',
#  'min',
#  'minute',
#  'month',
#  'now',
#  'replace',
#  'resolution',
#  'second',
#  'strftime',
#  'strptime',
#  'time',
#  'timestamp',
#  'timetuple',
#  'timetz',
#  'today',
#  'toordinal',
#  'tzinfo',
#  'tzname',
#  'utcfromtimestamp',
#  'utcnow',
#  'utcoffset',
#  'utctimetuple',
#  'weekday',
# ...

# %%
# Veamos la documentacion de isoweekday
help(f1.isoweekday)
# Out:
# Help on built-in function isoweekday:
#
# isoweekday(...) method of datetime.datetime instance
#     Return the day of the week represented by the date.
#     Monday == 1 ... Sunday == 7

# %%
# Veamos la documentacion de weekday
help(f1.weekday)
# Out:
# Help on built-in function weekday:
#
# weekday(...) method of datetime.datetime instance
#     Return the day of the week represented by the date.
#     Monday == 0 ... Sunday == 6

# %%
# Tarea : Desarrollar a profundidad, al igual que con el modulo datetime, el modulo calendar
import calendar

# %%
help(calendar)
# Out:
# Help on module calendar:
#
# NAME
#     calendar - Calendar printing functions
#
# MODULE REFERENCE
#     https://docs.python.org/3.10/library/calendar.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     Note when comparing these calendars to the ones printed by cal(1): By
#     default, these calendars have Monday as the first day of the week, and
#     Sunday as the last (the European convention). Use setfirstweekday() to
#     set the first day of the week (0=Monday, 6=Sunday).
#
# CLASSES
#     builtins.ValueError(builtins.Exception)
#         IllegalMonthError
#         IllegalWeekdayError
#     builtins.object
#         Calendar
#             HTMLCalendar
# ...

# %%
# Miembros del modulo calendar
dir(calendar)
# Out:
# ['Calendar',
#  'EPOCH',
#  'FRIDAY',
#  'February',
#  'HTMLCalendar',
#  'IllegalMonthError',
#  'IllegalWeekdayError',
#  'January',
#  'LocaleHTMLCalendar',
#  'LocaleTextCalendar',
#  'MONDAY',
#  'SATURDAY',
#  'SUNDAY',
#  'THURSDAY',
#  'TUESDAY',
#  'TextCalendar',
#  'WEDNESDAY',
#  '_EPOCH_ORD',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_colwidth',
#  '_locale',
#  '_localized_day',
#  '_localized_month',
#  '_monthlen',
#  '_nextmonth',
#  '_prevmonth',
#  '_spacing',
#  'c',
#  'calendar',
#  'datetime',
#  'day_abbr',
#  'day_name',
#  'different_locale',
#  'error',
#  'firstweekday',
#  'format',
#  'formatstring',
#  'isleap',
#  'leapdays',
#  'main',
#  'mdays',
#  'month',
#  'month_abbr',
#  'month_name',
#  'monthcalendar',
#  'monthrange',
#  'prcal',
#  'prmonth',
#  'prweek',
#  'repeat',
#  'setfirstweekday',
#  'sys',
#  'timegm',
#  'week',
# ...

# %%
# Documentacion de IllegalMonthError
help(calendar.IllegalMonthError)
# Out:
# Help on class IllegalMonthError in module calendar:
#
# class IllegalMonthError(builtins.ValueError)
#  |  IllegalMonthError(month)
#  |
#  |  # Exceptions raised for bad input
#  |
#  |  Method resolution order:
#  |      IllegalMonthError
#  |      builtins.ValueError
#  |      builtins.Exception
#  |      builtins.BaseException
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, month)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __str__(self)
#  |      Return str(self).
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from builtins.ValueError:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
# ...

# %%
# Modulo GEEMAP
import geemap

# %%
help(geemap)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Help on package geemap:
#
# NAME
#     geemap - Top-level package for geemap.
#
# PACKAGE CONTENTS
#     ai
#     basemaps
#     cartoee
#     chart
#     cli
#     colormaps
#     common
#     conversion
#     core
# ...

# %% [markdown]
# # Implementacion de la clase Persona

# %%
# Implementemos nuestra propia clase Base (Clase Abstracta / Super Clase) : Clase Persona

# Persona :
  # Tiene una fecha de nacimiento (modulo datetime) : lista de tres numeros (yyyy, mm, dd)
    # Hay que tener ciertas consideraciones :
      # La primera componente de esta lista representa al año : desde 1900 hasta el presente año
      # La segunda componente de esta lista representa al mes : debe ser un numero entero del 1 al 12
      # La tercera componente de esta lista representa al dia : debe ser un entero de 1 a 31
  # Posee un dni (string de 8 caracteres)
  # Posee uno o más nombres : Dato de tipo lista
  # Posee un apellido paterno : Dato de tipo lista
  # Posee un apellido materno : Dato de tipo lista
  # Tiene un sexo : string de un solo caracter (M o F)
  # Puede comunicarse (devolver una cadena de caracteres)

# %%
class Persona:
  """
  Persona :
    Tiene una fecha de nacimiento (modulo datetime) : lista de tres numeros (yyyy, mm, dd)
      Hay que tener ciertas consideraciones :
        La primera componente de esta lista representa al año : desde 1900 hasta el presente año
        La segunda componente de esta lista representa al mes : debe ser un numero entero del 1 al 12
        La tercera componente de esta lista representa al dia : debe ser un entero de 1 a 31
    Posee un dni (string de 8 caracteres)
    Posee uno o más nombres : Dato de tipo lista
    Posee un apellido paterno : Dato de tipo lista
    Posee un apellido materno : Dato de tipo lista
    Tiene un sexo : string de un solo caracter (M o F)
    Puede comunicarse (devolver una cadena de caracteres)
  """

  # Constructor
  def __init__(self,
               fechaNac = [1932,3,26],
               dni = '66666666',
               nombre = ["Jose", "Luis"],
               apellido_paterno = ["Arevalo"],
               apellido_materno = ["De la Fuente"],
               sexo = "M"):
    """
    Constructor de la clase Persona
    """
    # 1) Verificaciones
    if isinstance(fechaNac, list) and isinstance(dni, str) and isinstance(nombre, list) and \
        isinstance(apellido_paterno, list) and isinstance(apellido_materno, list) and isinstance(sexo, str):
        if len(fechaNac) == 3 and len(dni) == 8 and (len(sexo) == 1):
          if isinstance(fechaNac[0], int) and fechaNac[0] >= 1900 and fechaNac[0] <= datetime.date.today().year:
            if isinstance(fechaNac[1], int) and fechaNac[1] >= 1 and fechaNac[1] <= 12 and fechaNac[1] <= datetime.date.today().month:
              if isinstance(fechaNac[2], int) and fechaNac[2] >= 1 and fechaNac[2] <= 31 and fechaNac[2] <= datetime.date.today().day:
                if sexo == "M" or sexo == "m" or sexo == "F" or sexo == "f":
                  self.fechaNac = fechaNac
                  self.dni = dni
                  self.nombre = nombre
                  self.apellido_paterno = apellido_paterno
                  self.apellido_materno = apellido_materno
                  self.sexo = sexo
    else:
      raise TypeError("Alguna entrada al momento de instanciar la clase Persona no es el tio de dato correcto")

  # Modifiquemos el metodo __repr__
  def __repr__(self):
    return "Instancia correctamente creada"
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
help(Persona)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Help on class Persona in module __main__:
#
# class Persona(builtins.object)
# ...

# %%
# Prueba1
Peruano1 = Persona()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
Peruano1
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Instancia correctamente creada

# %%
# Lista de miemrbos, metodos, atributos, constantes de un objeto de clase Persona
dir(Peruano1)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
# ...

# %%
#
Peruano1.fechaNac
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# [1932, 3, 26]

# %%
# En PIT146 hay 4578 alumnos
ListaPIT146 = []
for participantes in range(4578):
  ListaPIT146.append(Persona())

ListaPIT146
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# [Instancia correctamente creada,
#  Instancia correctamente creada,
#  Instancia correctamente creada,
#  Instancia correctamente creada,
#  Instancia correctamente creada,
#  Instancia correctamente creada,
# ...

# %%
# Participantes de indice 666
ListaPIT146[666].nombre
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['Jose', 'Luis']

# %%
# Otra instancia de la clase Persona
Peruano2 = Persona([1983, 5, 12])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
Peruano2
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Instancia correctamente creada

# %%
Peruano2.fechaNac
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# [1983, 5, 12]

# %%
# Accedamos al atributo nombre
Peruano2.nombre
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['Jose', 'Luis']

# %%
Peruano3 = Persona("m")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-c07599198b53> in <cell line: 1>()
# ...

# %%
Peruano4 = Persona(sexo = "F")
Peruano4.sexo
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 'F'

# %%
help(Peruano4)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Help on Persona in module __main__ object:
#
# class Persona(builtins.object)
# ...

# %%
Peruano5 = Persona([1988, 10, 12], "71951873", ["Mario"], ["Sota"], ["Cardenas"])
Peruano5
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Instancia correctamente creada

# %%
Peruano5.nombre
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-a813efd28e99> in <cell line: 1>()
# ...

# %% [markdown]
# ## Herencia Simple
# Bajo el supuesto que corrijieron la clase Persona. Implementemos la subclase Supervisor.

# %%
class Supervisor(Persona):
  """
  Clase que hereda Persona y define subclase : Supervisor
  """

  # Modifiquemos el metodo __init__ de la subclase Supervisor
  # Agreguemos el campo "rol" a los argumentos de la clase Persona
  def __init__(self, fechaNac, dni, nombre, apellido_paterno, apellido_materno, sexo, rol):
    """
    Constructor de la clase Supervisor
    """
    # Invoquemos al constructor de la clase Persona
    Persona.__init__(self, fechaNac, dni, nombre, apellido_paterno, apellido_materno, sexo)

    # Al objeto self le agregamos el nuevo atributo rol
    self.rol = rol

    # Agreguemos atributos internos al objeto self
    import os
    self.sistema_operativo = os.uname()[0]
    import datetime
    self.datetime_creacion = datetime.datetime.now()

    # El atributo tareas
    self.tareas = ["Contratos", "Impuestos", "MedidasSeguridad"]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
Super1 = Supervisor(fechaNac = [1975, 5,31],
                    dni = "12457889",
                    nombre = ["Julian"],
                    apellido_paterno = ["Zapata"],
                    apellido_materno = ["Urqueaga"],
                    sexo = "M",
                    rol = "Admin")
Super1
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Instancia correctamente creada
