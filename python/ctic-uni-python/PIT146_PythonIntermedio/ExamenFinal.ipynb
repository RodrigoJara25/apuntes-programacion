# %%
# Pregunta 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Pregunta 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Pregunta 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Pregunta 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Pregunta 5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Pregunta 6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Pregunta 7

# %% [markdown]
# ![image.png](data:image/png;base64,...)
