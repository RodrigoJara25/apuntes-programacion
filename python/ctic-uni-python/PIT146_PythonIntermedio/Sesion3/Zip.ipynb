# %%
# La funcion "filter" sobre diccionarios

# Consideremos un diccionario de datos
data1 = {"A":19, "B":2, "C":14, "D":1, "E":5}

# Formamos un diccionario con todos los que tengan un valor mayor a 12
dict(filter(lambda x:x[1]>12, data1.items()))  # items nos devuelve una lista de tuplas
# Out:
# {'A': 19, 'C': 14}

# %%
# Recuperemos de data1 aquellos valores cuya llave es "B"
dict(filter(lambda x:x[0]=="B", data1.items()))
# Out:
# {'B': 2}

# %%
# La funcion map sobre diccionarios

# Multipliquemos por un aleatorio a cada valor del diccionario data1
import random as rnd
dict(map(lambda x:(x[0], x[1]*rnd.randint(0,5)), data1.items()))
# Out:
# {'A': 38, 'B': 0, 'C': 28, 'D': 4, 'E': 20}

# %%
dict(map(lambda x:(x[0] + str(rnd.randint(1,2)), x[1]*rnd.randint(0,5)), data1.items()))
# Out:
# {'A2': 95, 'B2': 0, 'C1': 14, 'D2': 0, 'E2': 0}

# %%
# Reduce para diccionarios

# Suma de todos los valores de data1
from functools import reduce
reduce(lambda x,y:x + y[1], data1.items(), 0)
# Out:
# 41

# %% [markdown]
# # Funcion zip
# * Sirve para reorganizar listas
# * Como parametros admite un conjunto de listas
# * Lo que hace es tomar el elemento i-esimo de cada lista y unirlos en una tupla, despues une todas las tuplas en una sola lista

# %%
# Punto de partida : dos listas
# Consideremos una lista de nombres y otra de sus apellidos

# Definimos las listas / tuplas
ListaName1 = ["Adrian", "Jorge", "Alejandra", "Andrea", "Marta"]
ListaApellidosPat = ["Luna", "Torres", "Arambulo", "Cernades", "Echegaray"]

# Aplicamos la funcion zip : usa cada nombre con su correspondiente apellido y los empaqueta en una tupla
NombreApellido = list(zip(ListaName1, ListaApellidosPat))
NombreApellido
# Out:
# [('Adrian', 'Luna'),
#  ('Jorge', 'Torres'),
#  ('Alejandra', 'Arambulo'),
#  ('Andrea', 'Cernades'),
#  ('Marta', 'Echegaray')]
