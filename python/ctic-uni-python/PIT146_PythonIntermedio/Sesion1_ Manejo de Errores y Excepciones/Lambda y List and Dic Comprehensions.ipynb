# %%
# Topicos desarrollados en el curso basico

  # definicion de variables
  # Funciones : type, dir y help
  # Funcion : input y print
  # Estrucutra de decision y repeticion
  # Definicion de funciones en python
  # listas, tuplas y diccionarios
  # Primeros pasos con numpy

# %%
import this

# Imprime el Zen de Python
# Es un conjunto de reglas que nos enseña cómo deberías razonar al momento de
# escribir el codigo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Palabras resrvadas
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
# La palabra reservada 'is' tiene que ver con and, or, not e in

# %%
# keywords de control de flujo : if, elif, else
# keywords para iteraciones : for, while, else, breand, continue
# keywords para estructuras : def, pass, class, as, lambda
# keywords de retorno : return, yield
# keywords de importacion : import from as
# keywords de manejo de excepciones : try, except, raise, assert, finally
# keywords de variables : del, global, nonlocal

# %% [markdown]
# # Funciones Anonimas: lambda

# %%
# definimos una funcion que realiza una funcion matematica
import math as m
import random as rnd

def f1(x):
  return 0.5*x**(rnd.randint(333,666))

f1(1)
# Out:
# 0.5

# %%
# Usemos la palabra reservada lambda para definir a f1 (un solo argumento)

f1_anonima = lambda w : 0.5*w**(rnd.randint(333,666))
f1_anonima(1)
# Out:
# 0.5

# %%
# Otro ejemplo de uso de la palabra reservada lambda (dos o más argumentos)
suma3 = lambda x1, x2, x3 : print(x1+x2+x3)

y1 = suma3(-2,3,5)
y1
# Out:
# 6

# %%
# tipo de dato para y1
type(y1)
# Out:
# NoneType

# %%
# Puedo sumar tres listas con lambda

y2 = suma3([0.5,0.2,0.9],[],[4,5])
y2
# Out:
# [0.5, 0.2, 0.9, 4, 5]

# %% [markdown]
# # List Comprehensions

# %%
# Sintaxis
# listaOutput = [expresion for elemento in iterable]

# %%
# Generemos una lista con los cuadrados de los numeros del 1 al 10
[i**2 for i in range(1,11)]
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
# Agreguemos una condicional
cad = 'El dia de hoy inicio el curso de python intermedio en el PIT nacional'

# Construyamos una lista con todos los caracteres "a"
[c for c in cad if c == "a"]  # todos los c que están en 'cad' y son iguales a 'a'
# Out:
# ['a', 'a', 'a']

# %%
ListaNombres = ['Juan', 'Eduardo', 'Maria', 'Vanessa', 'Sofia']

# Obtengamos los nombres que tengan la letra "e"
[n for n in ListaNombres if "e" in n]
# Out:
# ['Vanessa']

# %%
# Consideremos todos los nombres excepto "Juan"
[x for x in ListaNombres if x != "Juan"]
# Out:
# ['Eduardo', 'Maria', 'Vanessa', 'Sofia']

# %%
# Contemos el número de caracteres de cada nombre alamcenado en ListaNombres
[len(x) for x in ListaNombres]
# Out:
# [4, 7, 5, 7, 5]

# %%
# Dict Comprehensions

# Un diccionario que tenga como llave el nombre y como valor
# la longitud de cada nombre
{c:len(c) for c in ListaNombres}
# Out:
# {'Juan': 4, 'Eduardo': 7, 'Maria': 5, 'Vanessa': 7, 'Sofia': 5}

# %% [markdown]
# # Manejo de errores y excepciones

# %%
#
c = 3.12
d = -3.6

#
h = c+d
h
# Out:
# -0.48

# %%
# Definamos un diccionario
Medallas = {"Pais1":12, "Pais2":3, "Pais3":5, "Pais4":0}

# %%
#
Medallas[Pais5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-5c2eb84d6246> in <cell line: 2>()
#       1 #
# ----> 2 Medallas[Pais5]
#
# NameError: name 'Pais5' is not defined

# %%
# Documentacion del metodo get para un dato de tipo dict
#Solo para diccionarios

help(Medallas.get)
# Out:
# Help on built-in function get:
#
# get(key, default=None, /) method of builtins.dict instance
#     Return the value for key if key is in the dictionary, else default.

# %%
Medallas.get("Pais5", "Pais no enocntrado en la base de datos")
# Out:
# 'Pais no enocntrado en la base de datos'

# %%
# Generemos una excepcion
p = (c+d)/0

f = d**p
f
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-30-333c90fa4948> in <cell line: 2>()
#       1 # Generemos una excepcion
# ----> 2 p = (c+d)/0
#       3
#       4 f = d**p
#       5 f
#
# ZeroDivisionError: float division by zero

# %%
# Otra excepcion
Tesis = "12" + 9.81
Tesis
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-8063ab352d22> in <cell line: 2>()
#       1 # Otra excepcion
# ----> 2 Tesis = "12" + 9.81
#       3 Tesis
#
# TypeError: can only concatenate str (not "float") to str

# %%
# Lista de excepciones integradas con python
dir(locals()["__builtins__"])
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
#  'ReferenceError',
#  'ResourceWarning',
#  'RuntimeError',
#  'RuntimeWarning',
#  'StopAsyncIteration',
#  'StopIteration',
#  'SyntaxError',
#  'SyntaxWarning',
#  'SystemError',
#  'SystemExit',
#  'TabError',
#  'TimeoutError',
#  'True',
#  'TypeError',
#  'UnboundLocalError',
#  'UnicodeDecodeError',
#  'UnicodeEncodeError',
#  'UnicodeError',
#  'UnicodeTranslateError',
#  'UnicodeWarning',
#  'UserWarning',
#  'ValueError',
#  'Warning',
#  'ZeroDivisionError',
#  '__IPYTHON__',
#  '__build_class__',
#  '__debug__',
#  '__doc__',
#  '__import__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'abs',
#  'aiter',
#  'all',
#  'anext',
#  'any',
#  'ascii',
#  'bin',
#  'bool',
#  'breakpoint',
#  'bytearray',
#  'bytes',
#  'callable',
#  'chr',
#  'classmethod',
#  'compile',
#  'complex',
#  'copyright',
#  'credits',
#  'delattr',
#  'dict',
#  'dir',
#  'display',
#  'divmod',
#  'enumerate',
#  'eval',
#  'exec',
#  'execfile',
#  'filter',
#  'float',
#  'format',
#  'frozenset',
#  'get_ipython',
#  'getattr',
#  'globals',
#  'hasattr',
#  'hash',
#  'help',
#  'hex',
#  'id',
#  'input',
#  'int',
#  'isinstance',
#  'issubclass',
#  'iter',
#  'len',
#  'license',
#  'list',
#  'locals',
#  'map',
#  'max',
#  'memoryview',
#  'min',
#  'next',
#  'object',
#  'oct',
#  'open',
#  'ord',
#  'pow',
#  'print',
#  'property',
#  'range',
#  'repr',
#  'reversed',
#  'round',
#  'runfile',
#  'set',
#  'setattr',
#  'slice',
#  'sorted',
#  'staticmethod',
#  'str',
#  'sum',
#  'super',
#  'tuple',
#  'type',
#  'vars',
#  'zip']

# %%
# Lista de excepciones

ListaExcepciones = ['ArithmeticError',
 'AssertionError',
 'AttributeError',
 'BaseException',
 'BlockingIOError',
 'BrokenPipeError',
 'BufferError',
 'BytesWarning',
 'ChildProcessError',
 'ConnectionAbortedError',
 'ConnectionError',
 'ConnectionRefusedError',
 'ConnectionResetError',
 'DeprecationWarning',
 'EOFError',
 'Ellipsis',
 'EncodingWarning',
 'EnvironmentError',
 'Exception',
 'FileExistsError',
 'FileNotFoundError',
 'FloatingPointError',
 'FutureWarning',
 'GeneratorExit',
 'IOError',
 'ImportError',
 'ImportWarning',
 'IndentationError',
 'IndexError',
 'InterruptedError',
 'IsADirectoryError',
 'KeyError',
 'KeyboardInterrupt',
 'LookupError',
 'MemoryError',
 'ModuleNotFoundError',
 'NameError',
 'NotADirectoryError',
 'NotImplemented',
 'NotImplementedError',
 'OSError',
 'OverflowError',
 'PendingDeprecationWarning',
 'PermissionError',
 'ProcessLookupError',
 'RecursionError',
 'ReferenceError',
 'ResourceWarning',
 'RuntimeError',
 'RuntimeWarning',
 'StopAsyncIteration',
 'StopIteration',
 'SyntaxError',
 'SyntaxWarning',
 'SystemError',
 'SystemExit',
 'TabError',
 'TimeoutError',
 'TypeError',
 'UnboundLocalError',
 'UnicodeDecodeError',
 'UnicodeEncodeError',
 'UnicodeError',
 'UnicodeTranslateError',
 'UnicodeWarning',
 'UserWarning',
 'ValueError',
 'Warning',
 'ZeroDivisionError']

# %%
len(ListaExcepciones)
# Out:
# 69

# %%
# Veamos la documentacion de FloatingPointError
help(FloatingPointError)

# La clase FloatingPointError es sub clase de ArithmeticError
# Out:
# Help on class FloatingPointError in module builtins:
#
# class FloatingPointError(ArithmeticError)
#  |  Floating point operation failed.
#  |
#  |  Method resolution order:
#  |      FloatingPointError
#  |      ArithmeticError
#  |      Exception
#  |      BaseException
#  |      object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from BaseException:
#  |
#  |  __delattr__(self, name, /)
#  |      Implement delattr(self, name).
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __reduce__(...)
#  |      Helper for pickle.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __setattr__(self, name, value, /)
#  |      Implement setattr(self, name, value).
#  |
#  |  __setstate__(...)
#  |
#  |  __str__(self, /)
#  |      Return str(self).
#  |
#  |  with_traceback(...)
#  |      Exception.with_traceback(tb) --
#  |      set self.__traceback__ to tb and return self.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from BaseException:
#  |
#  |  __cause__
#  |      exception cause
#  |
#  |  __context__
#  |      exception context
#  |
#  |  __dict__
#  |
#  |  __suppress_context__
#  |
#  |  __traceback__
#  |
#  |  args

# %%
# Documentacion de ArithmeticError
help(ArithmeticError)

# Es sub clase de la clase Exception
# Out:
# Help on class ArithmeticError in module builtins:
#
# class ArithmeticError(Exception)
#  |  Base class for arithmetic errors.
#  |
#  |  Method resolution order:
#  |      ArithmeticError
#  |      Exception
#  |      BaseException
#  |      object
#  |
#  |  Built-in subclasses:
#  |      FloatingPointError
#  |      OverflowError
#  |      ZeroDivisionError
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from BaseException:
#  |
#  |  __delattr__(self, name, /)
#  |      Implement delattr(self, name).
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __reduce__(...)
#  |      Helper for pickle.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __setattr__(self, name, value, /)
#  |      Implement setattr(self, name, value).
#  |
#  |  __setstate__(...)
#  |
#  |  __str__(self, /)
#  |      Return str(self).
#  |
#  |  with_traceback(...)
#  |      Exception.with_traceback(tb) --
#  |      set self.__traceback__ to tb and return self.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from BaseException:
#  |
#  |  __cause__
#  |      exception cause
#  |
#  |  __context__
#  |      exception context
#  |
#  |  __dict__
#  |
#  |  __suppress_context__
#  |
#  |  __traceback__
#  |
#  |  args
